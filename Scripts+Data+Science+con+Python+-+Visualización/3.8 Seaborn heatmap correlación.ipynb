# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_mot = pd.read_csv(r'C:\Users\ivan_pinar\Dropbox\Creación de MOCs\MOC Master Python Análisis de Datos\Datasets\9.8\datasets_1489_2704_auto-mpg_cont.csv',encoding = "ISO-8859-1",delimiter=',')

# %%
df_mot
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name continent
# 0            70       1  chevrolet chevelle malibu   America
# 1            70       1          buick skylark 320   America
# 2            70       1         plymouth satellite   America
# 3            70       1              amc rebel sst   America
# 4            70       1                ford torino   America
# ..          ...     ...                        ...       ...
# 387          82       1            ford mustang gl   America
# 388          82       2                  vw pickup   America
# 389          82       1              dodge rampage   America
# 390          82       1                ford ranger   America
# 391          82       1                 chevy s-10   America
#
# [392 rows x 10 columns]

# %%
corr = df_mot.corr()

# %%
corr
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# model year    0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration  model year    origin
# mpg               0.423329    0.580541  0.565209
# cylinders        -0.504683   -0.345647 -0.568932
# displacement     -0.543800   -0.369855 -0.614535
# horsepower       -0.689196   -0.416361 -0.455171
# weight           -0.416839   -0.309120 -0.585005
# acceleration      1.000000    0.290316  0.212746
# model year        0.290316    1.000000  0.181528
# origin            0.212746    0.181528  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns.values,yticklabels=corr.columns.values, cmap='RdYlGn')

# %% [markdown]
# # Ejercicio

# %%
df_mot.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name continent
# 0          70       1  chevrolet chevelle malibu   America
# 1          70       1          buick skylark 320   America
# 2          70       1         plymouth satellite   America
# 3          70       1              amc rebel sst   America
# 4          70       1                ford torino   America

# %%
corr80 = df_mot[df_mot["model year"]==80].corr()

# %%
corr80
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.175640     -0.638594   -0.574985 -0.651394
# cylinders    -0.175640   1.000000      0.697533    0.355624  0.505889
# displacement -0.638594   0.697533      1.000000    0.594014  0.867010
# horsepower   -0.574985   0.355624      0.594014    1.000000  0.545584
# weight       -0.651394   0.505889      0.867010    0.545584  1.000000
# acceleration  0.190269  -0.010506      0.008140   -0.655333  0.174018
# model year         NaN        NaN           NaN         NaN       NaN
# origin        0.451890  -0.160209     -0.517215   -0.131125 -0.466425
#
#               acceleration  model year    origin
# mpg               0.190269         NaN  0.451890
# cylinders        -0.010506         NaN -0.160209
# displacement      0.008140         NaN -0.517215
# horsepower       -0.655333         NaN -0.131125
# weight            0.174018         NaN -0.466425
# acceleration      1.000000         NaN -0.233307
# model year             NaN         NaN       NaN
# origin           -0.233307         NaN  1.000000

# %%
sns.heatmap(corr80,xticklabels=corr80.columns.values,yticklabels=corr80.columns.values, cmap='RdYlGn')
