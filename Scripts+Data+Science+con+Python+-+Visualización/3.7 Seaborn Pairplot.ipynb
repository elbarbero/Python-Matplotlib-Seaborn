# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_mot = pd.read_csv(r'C:\Users\ivan_pinar\Dropbox\Creación de MOCs\MOC Master Python Análisis de Datos\Datasets\9.7\datasets_1489_2704_auto-mpg_cont.csv',encoding = "ISO-8859-1",delimiter=',')

# %%
df_mot.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name continent
# 0          70       1  chevrolet chevelle malibu   America
# 1          70       1          buick skylark 320   America
# 2          70       1         plymouth satellite   America
# 3          70       1              amc rebel sst   America
# 4          70       1                ford torino   America

# %%
sns.pairplot(df_mot)

# %%
sns.pairplot(df_mot,hue="continent")
