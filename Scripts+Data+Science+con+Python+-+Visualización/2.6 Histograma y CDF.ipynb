# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df_temp = pd.read_excel(r'C:\Users\ivan_pinar\Dropbox\Creación de MOCs\MOC Master Python Análisis de Datos\Datasets\8.6\Temperaturas.xlsx',sheet_name="Sheet1")

# %%
df_temp["T.Promedio"]=(df_temp["T. Máxima"]+df_temp["T.Mínima"])/2

# %%
plt.hist(df_temp["T.Promedio"],bins=50)
plt.title("¿Cuál es la distribución de temperatura?")
# Out:
# Text(0.5, 1.0, '¿Cuál es la distribución de temperatura?')

# %%
plt.hist(df_temp["T.Promedio"],bins=50,cumulative=True,density=True)
plt.title("¿Cuál es la CDF de la temperatura?")
# Out:
# Text(0.5, 1.0, '¿Cuál es la CDF de la temperatura?')
